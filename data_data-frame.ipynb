# %%
import urllib
import json
import pandas as pd

file = 'output201611.json'

df = pd.read_json(file)

with open(file) as train_file:
    dict_train = json.load(train_file)

# converting json dataset from dictionary to dataframe
train = pd.DataFrame.from_dict(dict_train, orient='index')
train.reset_index(level=0, inplace=True)

# %%
import pandas as pd
data = pd.read_csv("SocScrape-cleaned.csv")
data.head()
data
# Out:
#                                               Column 1  \
# 0    I don’t blame this poor nitwit. I blame leftis...
# 1    ‘Nazi’s Weren’t Socialists’ Says SJW History M...
# 2                  Socialism is on the rise in America
# 3                                                  NaN
# 4    Socialism was tried 100 times in the 100 years...
# 5                                                  NaN
# 6    Check out this exchange with a college socialist!
# 7                                                  NaN
# 8                                                 RT!!
# 9    In Tennessee, @realdonaldtrump echoes a Super ...
# 10   Check out this truck following the @GavinNewso...
# 11   If Chuck Schumer and Nancy Pelosi gain the maj...
# 12   Raise your hand if you oppose both national an...
# 13   “Ted Cruz says he supports veterans, but he ha...
# 14                                                 NaN
# 15   Republicans like Cruz love to send troops to w...
# 16   As stated by @sol651, unfortunately "...only V...
# 17                       Socialism is a contradiction.
# 18                  It's a contradiction to everything
# 19                                             I know.
# 20                                                 NaN
# 21                            Consumption cannot begin
# 22                           until production happens.
# 23   That which destroys production destroys consum...
# 24                                                 NaN
# 25                      Socialism destroys production.
# 26                                                 NaN
# 27                                        Which means,
# 28                              Socialism is actually,
# 29                                   the enemy of man.
# ..                                                 ...
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
#
#                                               Column 2  \
# 0    If Chuck Schumer and Nancy Pelosi gain the maj...
# 1                  Socialism is on the rise in America
# 2                                                  NaN
# 3    Socialism was tried 100 times in the 100 years...
# 4                                                  NaN
# 5    Check out this exchange with a college socialist!
# 6                                                  NaN
# 7                                                 RT!!
# 8    Raise your hand if you oppose both national an...
# 9    I don’t blame this poor nitwit. I blame leftis...
# 10   ‘Nazi’s Weren’t Socialists’ Says SJW History M...
# 11                 Say no to socialism! #MAGA #redwave
# 12   “Ted Cruz says he supports veterans, but he ha...
# 13                                                 NaN
# 14   Republicans like Cruz love to send troops to w...
# 15   Socialism, Marxism, Communism, Progressivism.....
# 16   I voted Conservative (decades ago), before I r...
# 17                                                 NaN
# 18                           Have you ever voted Tory?
# 19       (RT to increase sample size) #SocialistSunday
# 20   “Socialism in general has a record of failure ...
# 21   Donald Trump Walks Away from Being a Socialist...
# 22                                  Haters gonna hate.
# 23                       Socialism is a contradiction.
# 24                  It's a contradiction to everything
# 25                                             I know.
# 26                                                 NaN
# 27                            Consumption cannot begin
# 28                           until production happens.
# 29   That which destroys production destroys consum...
# ..                                                 ...
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
#
#                                               Column 3
# 0    If Chuck Schumer and Nancy Pelosi gain the maj...
# 1                  Socialism is on the rise in America
# 2                                                  NaN
# 3    Socialism was tried 100 times in the 100 years...
# 4                                                  NaN
# 5    Check out this exchange with a college socialist!
# 6                                                  NaN
# 7                                                 RT!!
# 8    From the man's own mouth- it would be illegal ...
# 9                      Tony Benn, Labour Party legend.
# 10   @jeremycorbyn & @johnmcdonnellMP do you agree ...
# 11                We cannot overlook Labour's history.
# 12                                                   …
# 13   I don’t blame this poor nitwit. I blame leftis...
# 14   ‘Nazi’s Weren’t Socialists’ Says SJW History M...
# 15   Raise your hand if you oppose both national an...
# 16   The historical record is clear: Everywhere it ...
# 17                                                 NaN
# 18   It’s a cautionary tale—one that should be taug...
# 19   “Ted Cruz says he supports veterans, but he ha...
# 20                                                 NaN
# 21   Republicans like Cruz love to send troops to w...
# 22                 Say no to socialism! #MAGA #redwave
# 23   Belgian social democrat Henri de Man against M...
# 24   I voted Conservative (decades ago), before I r...
# 25                                                 NaN
# 26                           Have you ever voted Tory?
# 27       (RT to increase sample size) #SocialistSunday
# 28   Socialism, Marxism, Communism, Progressivism.....
# 29   Are you aware that there are two definitions t...
# ..                                                 ...
# 102  #Florida do not vote for higher taxes and soci...
# 103  Please, please, please, save Florida and keep ...
# 104  The fact that this guy paid six figures for a ...
# 105  Lovely way to spend #SocialistSunday at the No...
# 106                    Socialism is alive and kicking.
# 107  My View: When You Consider The Fact That #Trum...
# 108  Won’t be visiting LuLus after brother Jimmy Bu...
# 109  We  @365AtlTraveler's A+ list of "Most Loved O...
# 110  Hey socialist shitheads, Bernout Sanders was c...
# 111  Florida does not support  Socialism  . We aren...
# 112  It's a prosperous economy that we will build, ...
# 113                                    John McDonnell.
# 114                                            #Labour
# 115        #Socialism: The permanent “austerity plan.”
# 116                                         #Venezuela
# 117  prison abolition and decarceration may seem id...
# 118  The EFF's policies(socialism) was tested over ...
# 119                           A right is not a service
# 120                      and a service is not a right.
# 121                             When are right becomes
# 122                                         a service,
# 123                                 it is not a right,
# 124                                     it is slavery.
# 125                           From a right to slavery.
# 126                  Evidently, the socialists believe
# 127                              that slavery is right
# 128                              and right is slavery.
# 129                                         Socialism,
# 130                          a contradiction in terms.
# 131  Two leaders who put their countries first and ...
#
# [132 rows x 3 columns]
